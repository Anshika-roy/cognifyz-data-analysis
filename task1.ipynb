# %%
# Task 1: Top Cuisines Analysis

import pandas as pd

df = pd.read_csv("Dataset .csv")

cuisines = df['Cuisines'].dropna().str.split(', ')

# %%
import pandas as pd

df = pd.read_csv("Dataset .csv")

cuisines = df['Cuisines'].dropna().str.split(', ')

# %%
total_restaurants = len(df)
percentage_by_cuisine = {}

for cuisine_name in top_three_cuisines.index:
    num_restaurants_with_cuisine = df['Cuisines'].dropna().apply(lambda x: cuisine_name in x).sum()
    percentage = (num_restaurants_with_cuisine / total_restaurants) * 100
    percentage_by_cuisine[cuisine_name] = percentage

display("Percentage of restaurants serving each of the top cuisines:", pd.Series(percentage_by_cuisine))
# Out:
# 'Percentage of restaurants serving each of the top cuisines:'
# North Indian    41.461627
# Chinese         28.614805
# Fast Food       20.804104
# dtype: float64

# %%
# Flatten the list of cuisines and count their occurrences
all_cuisines = [cuisine for sublist in cuisines for cuisine in sublist]
cuisine_counts = pd.Series(all_cuisines).value_counts()

# Get the top 3 most common cuisines
top_three_cuisines = cuisine_counts.head(3)
display("Top 3 Most Common Cuisines:", top_three_cuisines)
# Out:
# 'Top 3 Most Common Cuisines:'
# North Indian    3960
# Chinese         2735
# Fast Food       1986
# Name: count, dtype: int64
